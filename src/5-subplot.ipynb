# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

import matplotlib.pyplot as plt

x_line=[1,2,3,4,5]
y_line=[1,4,9,16,25]

x_bar=["A","B","C","D"]
y_bar=[5,7,3,9]
bar_colors=["red","blue","green","orange"]

x_scatter=[1,2,3,4,5]
y_scatter=[2,4,6,8,10]

pie_labels=["Python","Java","C++","Javascript"]
pie_sizes=[40,25,20,15]

fig,axs=plt.subplots(2,2,figsize=(10,8))

axs[0,0].plot(x_line,marker="o",color="blue")
axs[0,0].set_title("Line Chart")
axs[0,0].set_xlabel("x")
axs[0,0].set_ylabel("y")

axs[0,1].bar(x_bar,y_bar,color=bar_colors)
axs[0,1].set_title("Bar chart")
axs[0,1].set_xlabel("x")
axs[0,1].set_ylabel("y")

axs[1,0].scatter(x_scatter,y_scatter,color="purple")
axs[1,0].set_title("Scatter Plot")
axs[1,0].set_xlabel("x")
axs[1,0].set_ylabel("y")
                     
axs[1,1].pie(pie_sizes,labels=pie_labels,autopct="%1.1f%%",startangle=90)
axs[1,1].set_title("Pie Chart")
axs[1,1].axis("equal")

plt.tight_layout()
plt.show()
